# %% [markdown]
# # Leaf-Disease-Detection

# %% [markdown]
# ## Importing Libraries

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import layers,models
import matplotlib.pyplot as plt

# %% [markdown]
# ## Defing Hyperparameters

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS = 3
EPOCHS = 50

# %% [markdown]
# ## Importing Image Data

# %%
dataset = tf.keras.utils.image_dataset_from_directory(
    "Dataset",
    shuffle = True,
    image_size = (IMAGE_SIZE,IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
len(dataset)
# Out:
# 68

# %% [markdown]
# ## Realizing The Data

# %%
plt.figure(figsize = (10,10))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.axis("off")
        plt.title(class_names[label_batch[i]])

# %% [markdown]
# ## Train Test Validation Spliting

# %%
# // 80% ==> training
# // 20% ==> 10% validation, 10% test

# %%
train_size = 0.8
len(dataset)*train_size
# Out:
# 54.400000000000006

# %%
def get_dataset_partition_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    ds_size = len(ds)
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    if(shuffle):
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_ds = dataset.take(train_size)
    test_ds  = dataset.skip(train_size)
    val_ds   = test_ds.take(val_size)
    test_ds  = test_ds.skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partition_tf(dataset)

# %%
print(len(train_ds),len(val_ds),len(test_ds))
# Out:
# 54 6 8

# %% [markdown]
# ## Data Preprocessing

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandomRotation(0.2),
])

# %% [markdown]
# # Building The Model

# %%
input_shape = [BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS]
n_classes = 3

# %%
model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32, kernel_size=(3,3), activation='relu', input_shape = input_shape),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64, activation = 'relu'),
    layers.Dense(n_classes, activation = 'softmax'),
])

model.build(input_shape = input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (32, 256, 256, 3)         0
# _________________________________________________________________
# sequential_1 (Sequential)    (32, 256, 256, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (32, 254, 254, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (32, 127, 127, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (32, 125, 125, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (32, 62, 62, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (32, 60, 60, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (32, 30, 30, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (32, 28, 28, 64)          36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (32, 14, 14, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (32, 12, 12, 64)          36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (32, 6, 6, 64)            0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (32, 4, 4, 64)            36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (32, 2, 2, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (32, 256)                 0
# _________________________________________________________________
# dense (Dense)                (32, 64)                  16448
# _________________________________________________________________
# dense_1 (Dense)              (32, 3)                   195
# =================================================================
# Total params: 183,747
# Trainable params: 183,747
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics = ['accuracy']
)

# %% [markdown]
# ## Model Training

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data = val_ds,
    verbose=1,
    epochs = EPOCHS,
)
# Out:
# Epoch 1/50
# 54/54 [==============================] - 133s 2s/step - loss: 0.9147 - accuracy: 0.4878 - val_loss: 0.9881 - val_accuracy: 0.4271
# Epoch 2/50
# 54/54 [==============================] - 128s 2s/step - loss: 0.7037 - accuracy: 0.6701 - val_loss: 0.5371 - val_accuracy: 0.7396
# Epoch 3/50
# 54/54 [==============================] - 127s 2s/step - loss: 0.3793 - accuracy: 0.8426 - val_loss: 0.4806 - val_accuracy: 0.7500
# Epoch 4/50
# 54/54 [==============================] - 127s 2s/step - loss: 0.2541 - accuracy: 0.9028 - val_loss: 0.3198 - val_accuracy: 0.8594
# Epoch 5/50
# 54/54 [==============================] - 127s 2s/step - loss: 0.2348 - accuracy: 0.9051 - val_loss: 0.2505 - val_accuracy: 0.9115
# Epoch 6/50
# 54/54 [==============================] - 127s 2s/step - loss: 0.2477 - accuracy: 0.8877 - val_loss: 0.3261 - val_accuracy: 0.8542
# Epoch 7/50
# 54/54 [==============================] - 127s 2s/step - loss: 0.1729 - accuracy: 0.9317 - val_loss: 0.1445 - val_accuracy: 0.9427
# Epoch 8/50
# 54/54 [==============================] - 127s 2s/step - loss: 0.1294 - accuracy: 0.9491 - val_loss: 0.2167 - val_accuracy: 0.9062
# Epoch 9/50
# 54/54 [==============================] - 127s 2s/step - loss: 0.1574 - accuracy: 0.9358 - val_loss: 0.1720 - val_accuracy: 0.9115
# Epoch 10/50
# 54/54 [==============================] - 409s 8s/step - loss: 0.1081 - accuracy: 0.9659 - val_loss: 0.1143 - val_accuracy: 0.9531
# Epoch 11/50
# 54/54 [==============================] - 127s 2s/step - loss: 0.1346 - accuracy: 0.9514 - val_loss: 0.1297 - val_accuracy: 0.9427
# Epoch 12/50
# 54/54 [==============================] - 127s 2s/step - loss: 0.0903 - accuracy: 0.9699 - val_loss: 0.1265 - val_accuracy: 0.9427
# Epoch 13/50
# 54/54 [==============================] - 127s 2s/step - loss: 0.1017 - accuracy: 0.9670 - val_loss: 0.1589 - val_accuracy: 0.9167
# Epoch 14/50
# 54/54 [==============================] - 122s 2s/step - loss: 0.1330 - accuracy: 0.9468 - val_loss: 0.1100 - val_accuracy: 0.9635
# Epoch 15/50
# 54/54 [==============================] - 75s 1s/step - loss: 0.0686 - accuracy: 0.9780 - val_loss: 0.1196 - val_accuracy: 0.9583
# Epoch 16/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0705 - accuracy: 0.9716 - val_loss: 0.0780 - val_accuracy: 0.9635
# Epoch 17/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0528 - accuracy: 0.9797 - val_loss: 0.0828 - val_accuracy: 0.9635
# Epoch 18/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0529 - accuracy: 0.9809 - val_loss: 0.0581 - val_accuracy: 0.9688
# Epoch 19/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0305 - accuracy: 0.9925 - val_loss: 0.0450 - val_accuracy: 0.9792
# Epoch 20/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0351 - accuracy: 0.9890 - val_loss: 0.0525 - val_accuracy: 0.9844
# Epoch 21/50
# 54/54 [==============================] - 75s 1s/step - loss: 0.0545 - accuracy: 0.9797 - val_loss: 0.1907 - val_accuracy: 0.9427
# Epoch 22/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0427 - accuracy: 0.9838 - val_loss: 0.0228 - val_accuracy: 0.9948
# Epoch 23/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0325 - accuracy: 0.9890 - val_loss: 0.0930 - val_accuracy: 0.9688
# Epoch 24/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0299 - accuracy: 0.9896 - val_loss: 0.0274 - val_accuracy: 0.9896
# Epoch 25/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0955 - accuracy: 0.9641 - val_loss: 0.0853 - val_accuracy: 0.9688
# Epoch 26/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0640 - accuracy: 0.9763 - val_loss: 0.0643 - val_accuracy: 0.9740
# Epoch 27/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0330 - accuracy: 0.9878 - val_loss: 0.0579 - val_accuracy: 0.9740
# Epoch 28/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0206 - accuracy: 0.9925 - val_loss: 0.2659 - val_accuracy: 0.9427
# Epoch 29/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0439 - accuracy: 0.9850 - val_loss: 0.0630 - val_accuracy: 0.9792
# Epoch 30/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0338 - accuracy: 0.9873 - val_loss: 0.0805 - val_accuracy: 0.9688
# Epoch 31/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0329 - accuracy: 0.9890 - val_loss: 0.0623 - val_accuracy: 0.9792
# Epoch 32/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0303 - accuracy: 0.9902 - val_loss: 0.0908 - val_accuracy: 0.9688
# Epoch 33/50
# 54/54 [==============================] - 73s 1s/step - loss: 0.0751 - accuracy: 0.9751 - val_loss: 0.1306 - val_accuracy: 0.9635
# Epoch 34/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0517 - accuracy: 0.9815 - val_loss: 0.0329 - val_accuracy: 0.9792
# Epoch 35/50
# 54/54 [==============================] - 73s 1s/step - loss: 0.0181 - accuracy: 0.9925 - val_loss: 0.0724 - val_accuracy: 0.9844
# Epoch 36/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0196 - accuracy: 0.9931 - val_loss: 0.0665 - val_accuracy: 0.9844
# Epoch 37/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0405 - accuracy: 0.9861 - val_loss: 0.0567 - val_accuracy: 0.9792
# Epoch 38/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0660 - accuracy: 0.9769 - val_loss: 0.0427 - val_accuracy: 0.9948
# Epoch 39/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0227 - accuracy: 0.9925 - val_loss: 0.0589 - val_accuracy: 0.9844
# Epoch 40/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0257 - accuracy: 0.9913 - val_loss: 0.1552 - val_accuracy: 0.9583
# Epoch 41/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0184 - accuracy: 0.9942 - val_loss: 0.0337 - val_accuracy: 0.9896
# Epoch 42/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.0759 - val_accuracy: 0.9792
# Epoch 43/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0471 - accuracy: 0.9809 - val_loss: 0.0417 - val_accuracy: 0.9792
# Epoch 44/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0426 - accuracy: 0.9832 - val_loss: 0.0615 - val_accuracy: 0.9792
# Epoch 45/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0217 - accuracy: 0.9936 - val_loss: 0.0495 - val_accuracy: 0.9948
# Epoch 46/50
# 54/54 [==============================] - 73s 1s/step - loss: 0.0466 - accuracy: 0.9826 - val_loss: 0.0898 - val_accuracy: 0.9688
# Epoch 47/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0531 - accuracy: 0.9809 - val_loss: 0.0727 - val_accuracy: 0.9688
# Epoch 48/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0344 - accuracy: 0.9873 - val_loss: 0.0344 - val_accuracy: 0.9896
# Epoch 49/50
# 54/54 [==============================] - 73s 1s/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.0622 - val_accuracy: 0.9792
# Epoch 50/50
# 54/54 [==============================] - 74s 1s/step - loss: 0.0307 - accuracy: 0.9873 - val_loss: 0.0735 - val_accuracy: 0.9740

# %%
scores = model.evaluate(test_ds)
# Out:
# 8/8 [==============================] - 4s 320ms/step - loss: 0.0256 - accuracy: 0.9914

# %% [markdown]
# ## Measuring Performance

# %%
print(history)
print(history.params)
print(history.history.keys())

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']
# Out:
# <keras.callbacks.History object at 0x0000028D5E591610>
# {'verbose': 1, 'epochs': 50, 'steps': 54}
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
for image_batch, label_batch in test_ds.take(1):
    
    first_image = image_batch[0].numpy().astype('uint8')
    first_lable = label_batch[0].numpy()
    
    plt.imshow(first_image)
    print("the image is : ",class_names[first_lable])
    batch_prediction = model.predict(image_batch)
    
    print("the pridiction is : ",class_names[np.argmax(batch_prediction[0])])
# Out:
# the image is :  Potato___Early_blight
# the pridiction is :  Potato___Early_blight

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")

# %% [markdown]
# ## Saving The Model

# %%
import os
model_version = max([int(i) for i in os.listdir("saved_models") + [0]])+1
model.save(f"saved_models/{model_version}")
# Out:
# INFO:tensorflow:Assets written to: ../models/2\assets

# %%
model_version = 1
model.save(f"models/{model_version}")
# Out:
# INFO:tensorflow:Assets written to: models/1\assets

# %%
model.save("../potatoes.h5")
